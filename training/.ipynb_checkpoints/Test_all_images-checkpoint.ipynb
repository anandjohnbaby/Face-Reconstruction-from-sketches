# %% [markdown]
# # **Import Libraries**

# %%
import os
import numpy as np
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# # **Load Model and Specify Data path**

# %%
g_model = load_model("Models/g_model_epoch_000354.h5")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
input_folder = "CUHK\Testing sketch"
output_folder = r"Generated_Images"

# %%
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %% [markdown]
# # **Generate Image**

# %%
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        img_path = os.path.join(input_folder, filename)
        
        # Load and preprocess image
        img = load_img(img_path, target_size=(256, 256))
        img_array = img_to_array(img)
        norm_img = (img_array - 127.5) / 127.5  # Normalize to [-1, 1]
        
        # Generate the output image
        g_img = g_model.predict(np.expand_dims(norm_img, 0))[0]
        g_img = (g_img + 1) * 127.5  # Convert back to [0, 255]
        g_img = np.clip(g_img, 0, 255).astype(np.uint8)

        g_img = cv2.cvtColor(g_img, cv2.COLOR_RGB2BGR)

        # Save the generated image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, g_img)
        print(f"Processed and saved: {output_path}")

print("All images processed successfully!")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed and saved: Generated_Images\f-039-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Processed and saved: Generated_Images\f-040-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Processed and saved: Generated_Images\f-041-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Processed and saved: Generated_Images\f-042-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Processed and saved: Generated_Images\f-043-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Processed and saved: Generated_Images\f1-001-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Processed and saved: Generated_Images\f1-002-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Processed and saved: Generated_Images\f1-003-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Processed and saved: Generated_Images\f1-004-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# Processed and saved: Generated_Images\f1-005-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# Processed and saved: Generated_Images\f1-006-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# Processed and saved: Generated_Images\f1-007-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Processed and saved: Generated_Images\f1-008-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Processed and saved: Generated_Images\f1-009-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Processed and saved: Generated_Images\f1-010-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Processed and saved: Generated_Images\f1-011-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Processed and saved: Generated_Images\f1-012-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# Processed and saved: Generated_Images\f1-013-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# Processed and saved: Generated_Images\f1-014-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Processed and saved: Generated_Images\f1-015-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Processed and saved: Generated_Images\m-063-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# Processed and saved: Generated_Images\m-064-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# Processed and saved: Generated_Images\m-065-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Processed and saved: Generated_Images\m-066-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Processed and saved: Generated_Images\m-067-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Processed and saved: Generated_Images\m-068-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Processed and saved: Generated_Images\m-069-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# Processed and saved: Generated_Images\m-070-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Processed and saved: Generated_Images\m-071-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# Processed and saved: Generated_Images\m-072-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Processed and saved: Generated_Images\m-073-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# Processed and saved: Generated_Images\m-074-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Processed and saved: Generated_Images\m-075-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Processed and saved: Generated_Images\m-076-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# Processed and saved: Generated_Images\m-077-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Processed and saved: Generated_Images\m-078-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# Processed and saved: Generated_Images\m-079-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Processed and saved: Generated_Images\m-080-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# Processed and saved: Generated_Images\m-081-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# Processed and saved: Generated_Images\m-082-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# Processed and saved: Generated_Images\m-083-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Processed and saved: Generated_Images\m-084-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Processed and saved: Generated_Images\m-085-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# Processed and saved: Generated_Images\m-086-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Processed and saved: Generated_Images\m-087-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Processed and saved: Generated_Images\m-088-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Processed and saved: Generated_Images\m-089-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Processed and saved: Generated_Images\m-090-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Processed and saved: Generated_Images\m-091-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# Processed and saved: Generated_Images\m-092-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Processed and saved: Generated_Images\m-093-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# Processed and saved: Generated_Images\m-094-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# Processed and saved: Generated_Images\m-095-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Processed and saved: Generated_Images\m-096-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Processed and saved: Generated_Images\m-097-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# Processed and saved: Generated_Images\m-098-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# Processed and saved: Generated_Images\m-099-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Processed and saved: Generated_Images\m-100-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# Processed and saved: Generated_Images\m-101-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# Processed and saved: Generated_Images\m1-001-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step
# Processed and saved: Generated_Images\m1-002-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# Processed and saved: Generated_Images\m1-003-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# Processed and saved: Generated_Images\m1-004-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# Processed and saved: Generated_Images\m1-005-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# Processed and saved: Generated_Images\m1-006-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# Processed and saved: Generated_Images\m1-007-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# Processed and saved: Generated_Images\m1-008-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# Processed and saved: Generated_Images\m1-009-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Processed and saved: Generated_Images\m1-010-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Processed and saved: Generated_Images\m1-011-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# Processed and saved: Generated_Images\m1-012-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# Processed and saved: Generated_Images\m1-013-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Processed and saved: Generated_Images\m1-014-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Processed and saved: Generated_Images\m1-015-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Processed and saved: Generated_Images\m1-016-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Processed and saved: Generated_Images\m1-017-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Processed and saved: Generated_Images\m1-018-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Processed and saved: Generated_Images\m1-019-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# Processed and saved: Generated_Images\m1-020-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# Processed and saved: Generated_Images\m1-021-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# Processed and saved: Generated_Images\m1-022-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# Processed and saved: Generated_Images\m1-023-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# Processed and saved: Generated_Images\m1-024-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Processed and saved: Generated_Images\m1-025-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# Processed and saved: Generated_Images\m1-026-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Processed and saved: Generated_Images\m1-027-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Processed and saved: Generated_Images\m1-028-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Processed and saved: Generated_Images\m1-029-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Processed and saved: Generated_Images\m1-030-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Processed and saved: Generated_Images\m1-031-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# Processed and saved: Generated_Images\m1-032-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Processed and saved: Generated_Images\m1-033-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Processed and saved: Generated_Images\m1-034-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Processed and saved: Generated_Images\m1-035-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Processed and saved: Generated_Images\m1-036-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# Processed and saved: Generated_Images\m1-037-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# Processed and saved: Generated_Images\m1-038-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# Processed and saved: Generated_Images\m1-039-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# Processed and saved: Generated_Images\m1-040-01-sz1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Processed and saved: Generated_Images\m1-041-01-sz1.jpg
# All images processed successfully!
