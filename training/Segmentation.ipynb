# %%
import cv2
import numpy as np
import mediapipe as mp
import os

# Initialize Mediapipe Selfie Segmentation
mp_selfie_segmentation = mp.solutions.selfie_segmentation
segmentation_model = mp_selfie_segmentation.SelfieSegmentation(model_selection=1)

# Input and output directories
input_folder = r"D:\Projects\Main_Project\Face-Sketch-to-Image-Generation-using-GAN-master\Dataset_org\CUHK\Testing photo"
output_folder = r"D:\Projects\Main_Project\Face-Sketch-to-Image-Generation-using-GAN-master\Dataset_org\CUHK\Test_Mask"

# Create output folder if not exists
os.makedirs(output_folder, exist_ok=True)

# Process each image in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith((".jpg", ".png", ".jpeg")):
        image_path = os.path.join(input_folder, filename)
        
        # Load the image
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Get segmentation mask
        results = segmentation_model.process(image_rgb)
        mask = results.segmentation_mask

        # Convert mask to binary (thresholding)
        binary_mask = (mask > 0.5).astype(np.uint8) * 255  # Person -> White (255), Background -> Black (0)

        # Save the masked image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, binary_mask)

        print(f"Processed: {filename}")

print("Masking completed. Check the 'output_masks' folder.")
# Out:
# Processed: f-039-01.jpg
# Processed: f-040-01.jpg
# Processed: f-041-01.jpg
# Processed: f-042-01.jpg
# Processed: f-043-01.jpg
# Processed: f1-001-01.jpg
# Processed: f1-002-01.jpg
# Processed: f1-003-01.jpg
# Processed: f1-004-01.jpg
# Processed: f1-005-01.jpg
# Processed: f1-006-01.jpg
# Processed: f1-007-01.jpg
# Processed: f1-008-01.jpg
# Processed: f1-009-01.jpg
# Processed: f1-010-01.jpg
# Processed: f1-011-01.jpg
# Processed: f1-012-01.jpg
# Processed: f1-013-01.jpg
# Processed: f1-014-01.jpg
# Processed: f1-015-01.jpg
# Processed: m-063-01.jpg
# Processed: m-064-01.jpg
# Processed: m-065-01.jpg
# Processed: m-066-01.jpg
# Processed: m-067-01.jpg
# Processed: m-068-01.jpg
# Processed: m-069-01.jpg
# Processed: m-070-01.jpg
# Processed: m-071-01.jpg
# Processed: m-072-01.jpg
# Processed: m-073-01.jpg
# Processed: m-074-01.jpg
# Processed: m-075-01.jpg
# Processed: m-076-01.jpg
# Processed: m-077-01.jpg
# Processed: m-078-01.jpg
# Processed: m-079-01.jpg
# Processed: m-080-01.jpg
# Processed: m-081-01.jpg
# Processed: m-082-01.jpg
# Processed: m-083-01.jpg
# Processed: m-084-01.jpg
# Processed: m-085-01.jpg
# Processed: m-086-01.jpg
# Processed: m-087-01.jpg
# Processed: m-088-01.jpg
# Processed: m-089-01.jpg
# Processed: m-090-01.jpg
# Processed: m-091-01.jpg
# Processed: m-092-01.jpg
# Processed: m-093-01.jpg
# Processed: m-094-01.jpg
# Processed: m-095-01.jpg
# Processed: m-096-01.jpg
# Processed: m-097-01.jpg
# Processed: m-098-01.jpg
# Processed: m-099-01.jpg
# Processed: m-100-01.jpg
# Processed: m-101-01.jpg
# Processed: m1-001-01.jpg
# Processed: m1-002-01.jpg
# Processed: m1-003-01.jpg
# Processed: m1-004-01.jpg
# Processed: m1-005-01.jpg
# Processed: m1-006-01.jpg
# Processed: m1-007-01.jpg
# Processed: m1-008-01.jpg
# Processed: m1-009-01.jpg
# Processed: m1-010-01.jpg
# Processed: m1-011-01.jpg
# Processed: m1-012-01.jpg
# Processed: m1-013-01.jpg
# Processed: m1-014-01.jpg
# Processed: m1-015-01.jpg
# Processed: m1-016-01.jpg
# Processed: m1-017-01.jpg
# Processed: m1-018-01.jpg
# Processed: m1-019-01.jpg
# Processed: m1-020-01.jpg
# Processed: m1-021-01.jpg
# Processed: m1-022-01.jpg
# Processed: m1-023-01.jpg
# Processed: m1-024-01.jpg
# Processed: m1-025-01.jpg
# Processed: m1-026-01.jpg
# Processed: m1-027-01.jpg
# Processed: m1-028-01.jpg
# Processed: m1-029-01.jpg
# Processed: m1-030-01.jpg
# Processed: m1-031-01.jpg
# Processed: m1-032-01.jpg
# Processed: m1-033-01.jpg
# Processed: m1-034-01.jpg
# Processed: m1-035-01.jpg
# Processed: m1-036-01.jpg
# Processed: m1-037-01.jpg
# Processed: m1-038-01.jpg
# Processed: m1-039-01.jpg
# Processed: m1-040-01.jpg
# Processed: m1-041-01.jpg
# Masking completed. Check the 'output_masks' folder.
